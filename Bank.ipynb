# %%
import pandas as pd
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('bank')
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
df.tail()
# Out:
#        age          job  marital  education default  balance housing loan  \
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 11157  cellular   20   apr       257         1     -1         0  unknown
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 11157      no
# 11158      no
# 11159      no
# 11160      no
# ...

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'deposit']

# %%
df.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %%
df['deposit'].unique
# Out:
# <bound method Series.unique of 0        yes
# 1        yes
# 2        yes
# 3        yes
# 4        yes
#         ...
# 11157     no
# 11158     no
# 11159     no
# 11160     no
# 11161     no
# Name: deposit, Length: 11162, dtype: object>

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df['deposit'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        yes
# 1        yes
# 2        yes
# 3        yes
# 4        yes
#         ...
# 11157     no
# 11158     no
# 11159     no
# 11160     no
# 11161     no
# Name: deposit, Length: 11162, dtype: object>

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("/n")
# Out:
# 31    496
# 32    477
# 34    466
# 33    464
# 35    461
#      ...
# 92      2
# 93      2
# 88      2
# 95      1
# 89      1
# Name: age, Length: 76, dtype: int64
# /n
# management       2566
# blue-collar      1944
# technician       1823
# admin.           1334
# services          923
# retired           778
# self-employed     405
# student           360
# unemployed        357
# entrepreneur      328
# housemaid         274
# unknown            70
# Name: job, dtype: int64
# /n
# married     6351
# single      3518
# divorced    1293
# Name: marital, dtype: int64
# /n
# secondary    5476
# tertiary     3689
# primary      1500
# unknown       497
# Name: education, dtype: int64
# /n
# no     10994
# yes      168
# Name: default, dtype: int64
# /n
#  0       774
#  1        39
#  3        35
#  2        34
#  4        29
#         ...
#  5517      1
#  8332      1
#  4859      1
# -267       1
# -134       1
# Name: balance, Length: 3805, dtype: int64
# /n
# no     5881
# ...

# %%
df.shape
# Out:
# (11162, 17)

# %%
sns.scatterplot(x="age",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='deposit'>

# %%
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
sns.scatterplot(x="job",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='job', ylabel='deposit'>

# %%
sns.scatterplot(x="marital",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='marital', ylabel='deposit'>

# %%
sns.scatterplot(x="education",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='education', ylabel='deposit'>

# %%
sns.scatterplot(x="default",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='default', ylabel='deposit'>

# %%
sns.scatterplot(x="balance",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='balance', ylabel='deposit'>

# %%
sns.scatterplot(x="housing",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='housing', ylabel='deposit'>

# %%
sns.scatterplot(x="loan",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='loan', ylabel='deposit'>

# %%
sns.scatterplot(x="contact",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='contact', ylabel='deposit'>

# %%
sns.scatterplot(x="day",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='deposit'>

# %%
sns.scatterplot(x="month",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='deposit'>

# %%
sns.scatterplot(x="duration",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='duration', ylabel='deposit'>

# %%
sns.scatterplot(x="campaign",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='campaign', ylabel='deposit'>

# %%
sns.scatterplot(x="pdays",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='pdays', ylabel='deposit'>

# %%
sns.scatterplot(x="previous",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='previous', ylabel='deposit'>

# %%
sns.scatterplot(x="poutcome",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='poutcome', ylabel='deposit'>

# %%
sns.scatterplot(x="deposit",y='deposit',data=df)
# Out:
# <AxesSubplot:xlabel='deposit', ylabel='deposit'>

# %%
df.corr()
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.112300 -0.000762  0.000189 -0.005278  0.002774  0.020169
# balance   0.112300  1.000000  0.010467  0.022436 -0.013894  0.017411  0.030805
# day      -0.000762  0.010467  1.000000 -0.018511  0.137007 -0.077232 -0.058981
# duration  0.000189  0.022436 -0.018511  1.000000 -0.041557 -0.027392 -0.026716
# campaign -0.005278 -0.013894  0.137007 -0.041557  1.000000 -0.102726 -0.049699
# pdays     0.002774  0.017411 -0.077232 -0.027392 -0.102726  1.000000  0.507272
# previous  0.020169  0.030805 -0.058981 -0.026716 -0.049699  0.507272  1.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
import seaborn as sns
sns.heatmap(df.corr(),annot=True, linewidth=0.6, linecolor="orange",fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,7))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=11)
plt.yticks(fontsize=9)
plt.show()

# %%
collist=df.columns.values
ncol=16
nrows=20
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color="red",orient='v')
    plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21904\2303677578.py in <module>
#       5 for i in range(0,len(collist)):
#       6     plt.subplot(nrows,ncol,i+1)
# ----> 7     sns.boxplot(df[collist[i]],color="red",orient='v')
#       8     plt.tight_layout()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2241 ):
#    2242
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
# ...

# %%
df.skew()
# Out:
# age         0.862780
# balance     8.224619
# day         0.111330
# duration    2.143695
# campaign    5.545578
# pdays       2.449986
# previous    7.335298
# dtype: float64

# %%
sns.distplot(df["age"])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(df["balance"])
# Out:
# <AxesSubplot:xlabel='balance', ylabel='Density'>

# %%
sns.distplot(df["day"])
# Out:
# <AxesSubplot:xlabel='day', ylabel='Density'>

# %%
sns.distplot(df["duration"])
# Out:
# <AxesSubplot:xlabel='duration', ylabel='Density'>

# %%
sns.distplot(df["campaign"])
# Out:
# <AxesSubplot:xlabel='campaign', ylabel='Density'>

# %%
sns.distplot(df["pdays"])
# Out:
# <AxesSubplot:xlabel='pdays', ylabel='Density'>

# %%
sns.distplot(df["previous"])
# Out:
# <AxesSubplot:xlabel='previous', ylabel='Density'>

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome
# ...

# %%
y
# Out:
# 0        yes
# 1        yes
# 2        yes
# 3        yes
# 4        yes
#         ...
# 11157     no
# 11158     no
# 11159     no
# 11160     no
# 11161     no
# Name: deposit, Length: 11162, dtype: object

# %%
from scipy.stats import zscore
import numpy as np
