# %%
import pandas as pd
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('hr')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  \
# 0                   3              0     1                      0
# 1                   6              0     1                      0
# 2                   4              0     1                      0
# 3                   5              0     1                      0
# 4                   3              0     1                      0
#
#   Departments   salary
# 0        sales     low
# 1        sales  medium
# 2        sales  medium
# ...

# %%
df.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Departments  salary
# 14994                      0      support    low
# 14995                      0      support    low
# ...

# %%
df.isnull()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                   False            False           False
# 1                   False            False           False
# 2                   False            False           False
# 3                   False            False           False
# 4                   False            False           False
# ...                   ...              ...             ...
# 14994               False            False           False
# 14995               False            False           False
# 14996               False            False           False
# 14997               False            False           False
# 14998               False            False           False
#
#        average_montly_hours  time_spend_company  Work_accident   left  \
# 0                     False               False          False  False
# 1                     False               False          False  False
# ...

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Departments              0
# salary                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Departments            14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Departments ', 'salary'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['satisfaction_level',
#  'last_evaluation',
#  'number_project',
#  'average_montly_hours',
#  'time_spend_company',
#  'Work_accident',
#  'left',
#  'promotion_last_5years',
#  'Departments ',
#  'salary']

# %%
df['satisfaction_level'].unique()
# Out:
# array([0.38, 0.8 , 0.11, 0.72, 0.37, 0.41, 0.1 , 0.92, 0.89, 0.42, 0.45,
#        0.84, 0.36, 0.78, 0.76, 0.09, 0.46, 0.4 , 0.82, 0.87, 0.57, 0.43,
#        0.13, 0.44, 0.39, 0.85, 0.81, 0.9 , 0.74, 0.79, 0.17, 0.24, 0.91,
#        0.71, 0.86, 0.14, 0.75, 0.7 , 0.31, 0.73, 0.83, 0.32, 0.54, 0.27,
#        0.77, 0.88, 0.48, 0.19, 0.6 , 0.12, 0.61, 0.33, 0.56, 0.47, 0.28,
#        0.55, 0.53, 0.59, 0.66, 0.25, 0.34, 0.58, 0.51, 0.35, 0.64, 0.5 ,
#        0.23, 0.15, 0.49, 0.3 , 0.63, 0.21, 0.62, 0.29, 0.2 , 0.16, 0.65,
#        0.68, 0.67, 0.22, 0.26, 0.99, 0.98, 1.  , 0.52, 0.93, 0.97, 0.69,
#        0.94, 0.96, 0.18, 0.95])

# %%
df['satisfaction_level'].nunique()
# Out:
# 92

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("/n")
# Out:
# 0.10    358
# 0.11    335
# 0.74    257
# 0.77    252
# 0.84    247
#        ...
# 0.25     34
# 0.28     31
# 0.27     30
# 0.26     30
# 0.12     30
# Name: satisfaction_level, Length: 92, dtype: int64
# /n
# 0.55    358
# 0.50    353
# 0.54    350
# 0.51    345
# 0.57    333
#        ...
# 0.39     52
# 0.43     50
# 0.38     50
# 0.44     44
# 0.36     22
# Name: last_evaluation, Length: 65, dtype: int64
# /n
# 4    4365
# 3    4055
# 5    2761
# 2    2388
# 6    1174
# 7     256
# Name: number_project, dtype: int64
# /n
# 135    153
# 156    153
# 149    148
# 151    147
# 160    136
#       ...
# 297      7
# 288      6
# 299      6
# 96       6
# 303      6
# Name: average_montly_hours, Length: 215, dtype: int64
# /n
# 3     6443
# 2     3244
# 4     2557
# 5     1473
# 6      718
# 10     214
# 7      188
# 8      162
# Name: time_spend_company, dtype: int64
# /n
# 0    12830
# 1     2169
# Name: Work_accident, dtype: int64
# /n
# 0    11428
# 1     3571
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x="satisfaction_level",y='satisfaction_level',data=df)
# Out:
# <AxesSubplot:xlabel='satisfaction_level', ylabel='satisfaction_level'>

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
sns.scatterplot(x="last_evaluation",y='satisfaction_level',data=df)
# Out:
# <AxesSubplot:xlabel='last_evaluation', ylabel='satisfaction_level'>

# %%
sns.scatterplot(x="number_project",y='satisfaction_level',data=df)
# Out:
# <AxesSubplot:xlabel='number_project', ylabel='satisfaction_level'>

# %%
sns.scatterplot(x="average_montly_hours",y='satisfaction_level',data=df)
# Out:
# <AxesSubplot:xlabel='average_montly_hours', ylabel='satisfaction_level'>

# %%
sns.scatterplot(x="time_spend_company",y='satisfaction_level',data=df)
# Out:
# <AxesSubplot:xlabel='time_spend_company', ylabel='satisfaction_level'>

# %%
sns.scatterplot(x="Work_accident",y='satisfaction_level',data=df)
# Out:
# <AxesSubplot:xlabel='Work_accident', ylabel='satisfaction_level'>

# %%
sns.scatterplot(x="promotion_last_5years",y='satisfaction_level',data=df)
# Out:
# <AxesSubplot:xlabel='promotion_last_5years', ylabel='satisfaction_level'>

# %%
sns.scatterplot(x="left",y='satisfaction_level',data=df)
# Out:
# <AxesSubplot:xlabel='left', ylabel='satisfaction_level'>

# %%
sns.scatterplot(x="salary",y='satisfaction_level',data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='satisfaction_level'>

# %%
df.corr()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# last_evaluation                    0.339742            0.131591
# number_project                     0.417211            0.196786
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,9))
import seaborn as sns
sns.heatmap(df.corr(),annot=True, linewidth=0.8, linecolor="yellow",fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(18,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.show()

# %%
collist=df.columns.values
ncol=30
nrows=20
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color="red",orient='v')
    plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21972\1868973295.py in <module>
#       5 for i in range(0,len(collist)):
#       6     plt.subplot(nrows,ncol,i+1)
# ----> 7     sns.boxplot(df[collist[i]],color="red",orient='v')
#       8     plt.tight_layout()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2241 ):
#    2242
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
# ...

# %%
df.skew()
# Out:
# satisfaction_level      -0.476360
# last_evaluation         -0.026622
# number_project           0.337706
# average_montly_hours     0.052842
# time_spend_company       1.853319
# Work_accident            2.021149
# left                     1.230043
# promotion_last_5years    6.636968
# dtype: float64

# %%
sns.distplot(df["satisfaction_level"])
# Out:
# <AxesSubplot:xlabel='satisfaction_level', ylabel='Density'>

# %%
sns.distplot(df["last_evaluation"])
# Out:
# <AxesSubplot:xlabel='last_evaluation', ylabel='Density'>

# %%
sns.distplot(df["number_project"])
# Out:
# <AxesSubplot:xlabel='number_project', ylabel='Density'>

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
sns.distplot(df["average_montly_hours"])
# Out:
# <AxesSubplot:xlabel='average_montly_hours', ylabel='Density'>

# %%
sns.distplot(df["time_spend_company"])
# Out:
# <AxesSubplot:xlabel='time_spend_company', ylabel='Density'>

# %%
sns.distplot(df["Work_accident"])
# Out:
# <AxesSubplot:xlabel='Work_accident', ylabel='Density'>

# %%
sns.distplot(df["left"])
# Out:
# <AxesSubplot:xlabel='left', ylabel='Density'>

# %%
sns.distplot(df["promotion_last_5years"])
# Out:
# <AxesSubplot:xlabel='promotion_last_5years', ylabel='Density'>

# %%
x=df.iloc[:,:-2]
y=df.iloc[:,0]

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
x
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
y
# Out:
# 0        0.38
# 1        0.80
# 2        0.11
# 3        0.72
# 4        0.37
#          ...
# 14994    0.40
# 14995    0.37
# 14996    0.37
# 14997    0.11
# 14998    0.37
# Name: satisfaction_level, Length: 14999, dtype: float64

# %%
y.value_counts()
# Out:
# 0.10    358
# 0.11    335
# 0.74    257
# 0.77    252
# 0.84    247
#        ...
# 0.25     34
# 0.28     31
# 0.27     30
# 0.26     30
# 0.12     30
# Name: satisfaction_level, Length: 92, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import classification_report, confusion_matrix , roc_curve, accuracy_score

# %%
from sklearn .preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[-0.98837865, -1.08786785, -1.61322198, ..., -0.41116529,
#          1.788917  , -0.14741182],
#        [ 0.73840754,  0.84183559,  0.98209832, ..., -0.41116529,
#          1.788917  , -0.14741182],
#        [-1.78649733,  0.95768844,  2.22220879, ..., -0.41116529,
#          1.788917  , -0.14741182],
#        ...,
#        [-1.02213913, -1.08786785, -1.61322198, ..., -0.41116529,
#          1.788917  , -0.14741182],
#        [-1.78649733,  1.41994996,  1.63371373, ..., -0.41116529,
#          1.788917  , -0.14741182],
#        [-1.02213913, -1.1469205 , -1.61322198, ..., -0.41116529,
#          1.788917  , -0.14741182]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
       
x
# Out:
# array([[-0.98837865, -1.08786785, -1.61322198, ..., -0.41116529,
#          1.788917  , -0.14741182],
#        [ 0.73840754,  0.84183559,  0.98209832, ..., -0.41116529,
#          1.788917  , -0.14741182],
#        [-1.78649733,  0.95768844,  2.22220879, ..., -0.41116529,
#          1.788917  , -0.14741182],
#        ...,
#        [-1.02213913, -1.08786785, -1.61322198, ..., -0.41116529,
#          1.788917  , -0.14741182],
#        [-1.78649733,  1.41994996,  1.63371373, ..., -0.41116529,
#          1.788917  , -0.14741182],
#        [-1.02213913, -1.1469205 , -1.61322198, ..., -0.41116529,
#          1.788917  , -0.14741182]])

# %%
    
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        
        print("At random state",i,'The model performs very well')
        print("At random_state:",i)
        print("Training accuracy is :-",accuracy_score(y_train,pred_train)*100)
        print("Testing accuracy  is:-",accuracy_score(y_test,pred_test)*100)
        prediction = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21972\3103081678.py in <module>
#       1 x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
# ----> 2 lr.fit(x_train,y_train)
#       3 pred_train=lr.predict(x_train)
#       4 pred_test=lr.predict(x_test)
#       5 if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
# -> 1516         check_classification_targets(y)
#    1517         self.classes_ = np.unique(y)
#    1518
#
# ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     195         "multilabel-sequences",
# ...
