# %%
import pandas as pd
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('zomato')
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Restaurant ID',
#  'Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes']

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...     Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...    Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karak�_y, ��stanbul  28.977392  41.022793
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.isnull()
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
# 9548          False            False         False  False    False     False
# 9549          False            False         False  False    False     False
# 9550          False            False         False  False    False     False
#
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# Average Cost for two  predicting

# %%
df['Average Cost for two'].nunique()
# Out:
# 140

# %%
df['Average Cost for two'].unique()
# Out:
# array([  1100,   1200,   4000,   1500,   1000,   2000,   6000,    800,
#           900,    700,    850,    600,   3000,   1800,     55,     30,
#            45,     60,     50,     80,     90,    200,    150,    100,
#           230,    240,    350,    140,    170,    120,    250,     40,
#            70,    300,     85,     75,    400,     65,     25,     10,
#             0,     20,     35,      7,    270,    500,    430,    315,
#           220,     95,    190,    260,    180,    330,    280,    160,
#           285,    130,    110,   2500,   3600,    550,   1400,    450,
#           950,    650,   1300,   2400,   1600,   2200,    750,   1700,
#          1250,   1900,   2700,   3500,   5000,   2300,   1750,   3200,
#          2100,   1850,   4500,   3300,   1350,   1650,   1950,   1050,
#           290,   1450,   2800,   3650,   4800,   1550,    720,   6500,
#          7000,   1150,   2900,   2600,   4700,   3700,   3800,   4100,
# ...

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("/n")
# Out:
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: Restaurant ID, Length: 9551, dtype: int64
# /n
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
# /n
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
# /n
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# ...

# %%
sns.scatterplot(x="Restaurant ID",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Restaurant ID', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Restaurant Name",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Restaurant Name', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Country Code",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Country Code', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="City",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Address",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Address', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Locality",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Locality', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Locality Verbose",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Locality Verbose', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Longitude",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Average Cost for two'>

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
sns.scatterplot(x="Latitude",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Latitude', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Cuisines",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Cuisines', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Average Cost for two",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Average Cost for two', ylabel='Average Cost for two'>

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
sns.scatterplot(x="Currency",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Currency', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Has Table booking",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Has Table booking', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Has Online delivery",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Has Online delivery', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Is delivering now",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Is delivering now', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Switch to order menu",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Switch to order menu', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Price range",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Aggregate rating",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Rating color",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Rating text",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='Average Cost for two'>

# %%
sns.scatterplot(x="Votes",y='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Average Cost for two'>

# %%
df.corr()
# Out:
#                       Restaurant ID  Country Code  Longitude  Latitude  \
# Restaurant ID              1.000000      0.148471  -0.226081 -0.052081
# Country Code               0.148471      1.000000  -0.698299  0.019792
# Longitude                 -0.226081     -0.698299   1.000000  0.043207
# Latitude                  -0.052081      0.019792   0.043207  1.000000
# Average Cost for two      -0.001693      0.043225   0.045891 -0.111088
# Price range               -0.134540      0.243327  -0.078939 -0.166688
# Aggregate rating          -0.326212      0.282189  -0.116818  0.000516
# Votes                     -0.147023      0.154530  -0.085101 -0.022962
#
#                       Average Cost for two  Price range  Aggregate rating  \
# Restaurant ID                    -0.001693    -0.134540         -0.326212
# Country Code                      0.043225     0.243327          0.282189
# Longitude                         0.045891    -0.078939         -0.116818
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(23,12))
import seaborn as sns
sns.heatmap(df.corr(),annot=True, linewidth=0.8, linecolor="orange",fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,15))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.show()

# %%
df.skew()
# Out:
# Restaurant ID            0.061570
# Country Code             3.043965
# Longitude               -2.807328
# Latitude                -3.081635
# Average Cost for two    35.477915
# Price range              0.889618
# Aggregate rating        -0.954130
# Votes                    8.807637
# dtype: float64

# %%
sns.distplot(df["Restaurant ID"])
# Out:
# <AxesSubplot:xlabel='Restaurant ID', ylabel='Density'>

# %%
sns.distplot(df["Country Code"])
# Out:
# <AxesSubplot:xlabel='Country Code', ylabel='Density'>

# %%
sns.distplot(df["Longitude"])
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Density'>

# %%
sns.distplot(df["Latitude"])
# Out:
# <AxesSubplot:xlabel='Latitude', ylabel='Density'>

# %%
sns.distplot(df["Average Cost for two"])
# Out:
# <AxesSubplot:xlabel='Average Cost for two', ylabel='Density'>

# %%
sns.distplot(df["Price range"])
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Density'>

# %%
sns.distplot(df["Aggregate rating"])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Density'>

# %%
sns.distplot(df["Votes"])
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Density'>

# %%
x=df.iloc[ : , :]
y=df.iloc[:,-11]

# %%
x
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
y
# Out:
# 0       1100
# 1       1200
# 2       4000
# 3       1500
# 4       1500
#         ...
# 9546      80
# 9547     105
# 9548     170
# 9549     120
# 9550      55
# Name: Average Cost for two, Length: 9551, dtype: int64

# %%
y.value_counts()
# Out:
# 500       900
# 300       897
# 400       857
# 200       687
# 600       652
#          ...
# 8000        1
# 2350        1
# 150000      1
# 70000       1
# 545         1
# Name: Average Cost for two, Length: 140, dtype: int64

# %%
from scipy.stats import zscore
import numpy as np

# %%
from sklearn .preprocessing import power_transform
x=power_transform(x,method='Le Petit Souffle')
x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6604\1645684233.py in <module>
#       1 from sklearn .preprocessing import power_transform
# ----> 2 x=power_transform(x,method='Le Petit Souffle')
#       3 x
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in power_transform(X, method, standardize, copy)
#    3422     """
#    3423     pt = PowerTransformer(method=method, standardize=standardize, copy=copy)
# -> 3424     return pt.fit_transform(X)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit_transform(self, X, y)
#    3063             Transformed data.
#    3064         """
# -> 3065         return self._fit(X, y, force_transform=True)
#    3066
#    3067     def _fit(self, X, y=None, force_transform=False):
#
# ...

# %%
from imblearn.over_sampling import SMOTE
SM=SMOTE()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import classification_report, confusion_matrix , roc_curve, accuracy_score

# %%
for i in range(0,21):
    
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print("At random state",i,'The model performs very well')
        print("At random_state:",i)
        print("Training accuracy is :-",accuracy_score(y_train,pred_train)*100)
        print("Testing accuracy  is:-",accuracy_score(y_test,pred_test)*100)
        prediction = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6604\1262340892.py in <module>
#       2
#       3     x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
# ----> 4     lr.fit(x_train,y_train)
#       5     pred_train=lr.predict(x_train)
#       6     pred_test=lr.predict(x_test)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1506             _dtype = [np.float64, np.float32]
#    1507
# -> 1508         X, y = self._validate_data(
#    1509             X,
#    1510             y,
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
# price range predicting

# %%
df['Price range'].nunique()
# Out:
# 4

# %%
df['Price range'].unique()
# Out:
# array([3, 4, 2, 1], dtype=int64)

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("/n")
# Out:
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: Restaurant ID, Length: 9551, dtype: int64
# /n
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
# /n
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
# /n
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# ...

# %%
sns.scatterplot(x="Restaurant ID",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Restaurant ID', ylabel='Price range'>

# %%
sns.scatterplot(x="Restaurant Name",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Restaurant Name', ylabel='Price range'>

# %%
sns.scatterplot(x="Country Code",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Country Code', ylabel='Price range'>

# %%
sns.scatterplot(x="City",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Price range'>

# %%
sns.scatterplot(x="Address",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Address', ylabel='Price range'>

# %%
sns.scatterplot(x="Locality",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Locality', ylabel='Price range'>

# %%
sns.scatterplot(x="Locality Verbose",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Locality Verbose', ylabel='Price range'>

# %%
sns.scatterplot(x="Longitude",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Price range'>

# %%
sns.scatterplot(x="Latitude",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Latitude', ylabel='Price range'>

# %%
sns.scatterplot(x="Cuisines",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Cuisines', ylabel='Price range'>

# %%
sns.scatterplot(x="Average Cost for two",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Average Cost for two', ylabel='Price range'>

# %%
sns.scatterplot(x="Currency",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Currency', ylabel='Price range'>

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
sns.scatterplot(x="Has Table booking",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Has Table booking', ylabel='Price range'>

# %%
sns.scatterplot(x="Has Online delivery",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Has Online delivery', ylabel='Price range'>

# %%
sns.scatterplot(x="Is delivering now",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Is delivering now', ylabel='Price range'>

# %%
sns.scatterplot(x="Switch to order menu",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Switch to order menu', ylabel='Price range'>

# %%
sns.scatterplot(x="Price range",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Price range'>

# %%
sns.scatterplot(x="Aggregate rating",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Price range'>

# %%
sns.scatterplot(x="Rating color",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='Price range'>

# %%
sns.scatterplot(x="Rating text",y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='Price range'>

# %%
sns.scatterplot(x='Votes',y='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Price range'>

# %%
df.corr()
# Out:
#                       Restaurant ID  Country Code  Longitude  Latitude  \
# Restaurant ID              1.000000      0.148471  -0.226081 -0.052081
# Country Code               0.148471      1.000000  -0.698299  0.019792
# Longitude                 -0.226081     -0.698299   1.000000  0.043207
# Latitude                  -0.052081      0.019792   0.043207  1.000000
# Average Cost for two      -0.001693      0.043225   0.045891 -0.111088
# Price range               -0.134540      0.243327  -0.078939 -0.166688
# Aggregate rating          -0.326212      0.282189  -0.116818  0.000516
# Votes                     -0.147023      0.154530  -0.085101 -0.022962
#
#                       Average Cost for two  Price range  Aggregate rating  \
# Restaurant ID                    -0.001693    -0.134540         -0.326212
# Country Code                      0.043225     0.243327          0.282189
# Longitude                         0.045891    -0.078939         -0.116818
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,9))
import seaborn as sns
sns.heatmap(df.corr(),annot=True, linewidth=0.8, linecolor="orange",fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.show()

# %%
df.skew()
# Out:
# Restaurant ID            0.061570
# Country Code             3.043965
# Longitude               -2.807328
# Latitude                -3.081635
# Average Cost for two    35.477915
# Price range              0.889618
# Aggregate rating        -0.954130
# Votes                    8.807637
# dtype: float64

# %%
sns.distplot(df["Restaurant ID"])
# Out:
# <AxesSubplot:xlabel='Restaurant ID', ylabel='Density'>

# %%
sns.distplot(df["Country Code"])
# Out:
# <AxesSubplot:xlabel='Country Code', ylabel='Density'>

# %%
sns.distplot(df["Longitude"])
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Density'>

# %%
sns.distplot(df["Average Cost for two"])
# Out:
# <AxesSubplot:xlabel='Average Cost for two', ylabel='Density'>

# %%
sns.distplot(df["Price range"])
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Density'>

# %%
sns.distplot(df["Aggregate rating"])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Density'>

# %%
sns.distplot(df["Votes"])
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Density'>

# %%
sns.distplot(df["Latitude"])
# Out:
# <AxesSubplot:xlabel='Latitude', ylabel='Density'>

# %%
x=df.iloc[:,:]
y=df.iloc[:,-5]

# %%
y
# Out:
# 0       3
# 1       3
# 2       4
# 3       4
# 4       4
#        ..
# 9546    3
# 9547    3
# 9548    4
# 9549    4
# 9550    2
# Name: Price range, Length: 9551, dtype: int64

# %%
from scipy.stats import zscore
import numpy as np

# %%
from sklearn .preprocessing import power_transform

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
       
x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6604\1348371337.py in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc=StandardScaler()
# ----> 3 x=sc.fit_transform(x)
#       4
#       5 x
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
# ...
